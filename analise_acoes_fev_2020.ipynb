# %% [markdown]
# **Melhores ações para 2020: veja boas opções para investir:**

# %% [markdown]
# **Análise de uma ação negociada no mercado brasileiro com data sciente, escolhida com base de analistas e o site de referência logo abaixo:**
#
# **https://blog.toroinvestimentos.com.br/melhores-acoes-2020**
#
# **Empresas de energia elétrica: Taesa - TAEE11**
#
# **Mais informações sobre a companhia:**
# **https://institucional.taesa.com.br/**

# %% [markdown]
# *Importaremos uma figura para ilustrar o assunto: 'Análise Técnica' :*

# %%
from IPython.display import Image
Image(filename='analise_tecnica.jpg', width=1000, height=1000)

# %% [markdown]
# **Instalação do datareader**
#
# **https://readthedocs.org/projects/pandas-datareader/downloads/pdf/stable/**

# %%
! pip install pandas_datareader

# %%
# importar as bibliotecas necessárias:
import pandas as pd
from pandas_datareader import data as web
import plotly.graph_objects as go
 
# criar um DataFrame vazio:
df = pd.DataFrame()

# %%
# Ação do segmento elétrico selecionado:
acao = 'TAEE11.SA'
 
# A base de referência para o DataFrame será o Yahoo:
df = web.DataReader(acao, data_source='yahoo', start='01-01-2020')
 
# Verificação das 5 primeiras linhas:
df.head()
# Out:
#                  High        Low   Open      Close   Volume  Adj Close
# Date
# 2020-01-02  31.360001  30.780001  31.15  30.840000  1270600  30.840000
# 2020-01-03  30.969999  30.520000  30.84  30.969999  1786300  30.969999
# 2020-01-06  31.209999  30.650000  30.99  31.000000  2492400  31.000000
# 2020-01-07  30.990000  30.350000  30.99  30.740000  2553700  30.740000
# 2020-01-08  30.780001  29.920000  30.75  30.120001  2235600  30.120001

# %% [markdown]
# **Informação de como são os dados de cada coluna:**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29 entries, 2020-01-02 to 2020-02-11
# Data columns (total 6 columns):
# High         29 non-null float64
# Low          29 non-null float64
# Open         29 non-null float64
# Close        29 non-null float64
# Volume       29 non-null int64
# Adj Close    29 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 1.6 KB

# %% [markdown]
# **Formato de como é o banco de dados analisado:**

# %%
df.shape
# Out:
# (29, 6)

# %% [markdown]
# **Verificação se há dados faltante:**

# %%
df.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %% [markdown]
# **Número de dados de cada coluna:**

# %%
df.count()
# Out:
# High         29
# Low          29
# Open         29
# Close        29
# Volume       29
# Adj Close    29
# dtype: int64

# %% [markdown]
# **Descrição estatística das colunas:**

# %%
df.describe()
# Out:
#             High        Low       Open      Close        Volume  Adj Close
# count  29.000000  29.000000  29.000000  29.000000  2.900000e+01  29.000000
# mean   31.390000  30.805862  31.154827  31.130000  1.902493e+06  31.130000
# std     0.584411   0.589434   0.559506   0.588849  5.903375e+05   0.588849
# min    30.360001  29.700001  30.150000  30.120001  1.120500e+06  30.120001
# 25%    30.910000  30.360001  30.750000  30.740000  1.518500e+06  30.740000
# 50%    31.379999  30.780001  31.100000  30.969999  1.726900e+06  30.969999
# 75%    31.790001  31.250000  31.500000  31.500000  2.235600e+06  31.500000
# max    32.349998  31.860001  32.299999  32.209999  3.273900e+06  32.209999

# %% [markdown]
# **Verificação do valor mínimo presente na coluna "High"**

# %%
df[df['High'] == df['High'].min()]
# Out:
#                  High        Low   Open      Close   Volume  Adj Close
# Date
# 2020-01-09  30.360001  29.700001  30.15  30.280001  3078600  30.280001

# %% [markdown]
# **Verificação do valor máximo presente na coluna "High"**

# %%
df[df['High'] == df['High'].max()]
# Out:
#                  High        Low       Open  Close   Volume  Adj Close
# Date
# 2020-01-24  32.349998  31.860001  32.299999  32.02  1120500      32.02

# %% [markdown]
# **Representação do gráfico da ação TAEE11(TAESA) seguindo o formato de candlestick, utilizando os comandos python:**

# %%
# plotar o gráfico de candlestick
trace1 = {
    'x': df.index,
    'open': df.Open,
    'close': df.Close,
    'high': df.High,
    'low': df.Low,
    'type': 'candlestick',
    'name': acao,
    'showlegend': False
}
 
data = [trace1]
layout = go.Layout()
 
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="83537a23-4c51-46d8-a6a3-6fe2b87983c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("83537a23-4c51-46d8-a6a3-6fe2b87983c2")) {
#                     Plotly.newPlot(
#                         '83537a23-4c51-46d8-a6a3-6fe2b87983c2',
# ...
